# %%
# !pwd
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
import sys
sys.executable
# Out:
# /c/Users/81908/jupyter_notebook/tf_2_work/stock_work/chart_model/notebook
# 'C:\\Users\\81908\\Anaconda3\\envs\\tfgpu\\python.exe'

# %% [markdown]
# # 株価チャートの画像作成
# - https://note.com/inoichan/n/n97d0944d4e7d

# %%
import sys
sys.path.append(r'C:\Users\81908\jupyter_notebook\tf_2_work\stock_work\chart_model\code')
import make_chart_all

import datetime

code = 7974#2914

start_date = '2000-01-01'
d_start_date = datetime.datetime.strptime(start_date, '%Y-%m-%d').date()

d_end_date = d_start_date + datetime.timedelta(weeks=4 * 4 + 2)  # 4ヶ月半後までデータとる
print(d_start_date, d_end_date)

output_dir = r'D:\work\chart_model\output_new\tmp'
is_ticks = True
figsize = (10, 10)
    
df, label, df_last_date = make_chart_all.make_chart(code, d_start_date, d_end_date, output_dir=output_dir)
df, label, df_last_date = make_chart_all.make_chart(code, d_start_date, d_end_date, output_dir=output_dir, is_ticks=is_ticks, figsize=figsize)
print(label)
display(df)
display(df_last_date)

print(df_last_date.iloc[0])
print(df_last_date.iloc[-1])
# Out:
# 2000-01-01 2000-05-06
# 0
#                  date    close     25MA          75MA
# date
# 2000-01-04 2000-01-04  15870.0  16482.8  16850.133333
# 2000-01-05 2000-01-05  15900.0  16414.8  16822.666667
# 2000-01-06 2000-01-06  16060.0  16361.2  16791.866667
# 2000-01-07 2000-01-07  15900.0  16325.2  16753.333333
# 2000-01-11 2000-01-11  16500.0  16323.2  16736.400000
# ...               ...      ...      ...           ...
# 2000-04-26 2000-04-26  19550.0  17681.6  19518.266667
# 2000-04-27 2000-04-27  18060.0  17708.0  19547.066667
# 2000-04-28 2000-04-28  18000.0  17742.0  19567.066667
# 2000-05-01 2000-05-01  17940.0  17767.6  19570.933333
# 2000-05-02 2000-05-02  18450.0  17789.6  19570.533333
#
# [82 rows x 4 columns]
#          date    close
# 0  2000-05-02  18450.0
# 1  2000-05-08  18590.0
# 2  2000-05-09  17900.0
# 3  2000-05-10  17480.0
# 4  2000-05-11  16320.0
# 5  2000-05-12  17820.0
# 6  2000-05-15  16980.0
# 7  2000-05-16  17540.0
# 8  2000-05-17  17700.0
# ...

# %% [markdown]
# # データセット作成

# %%
import sys
sys.path.append(r'C:\Users\81908\jupyter_notebook\tf_2_work\stock_work\chart_model\code')
import make_dataset

dataset_dir = r'D:\work\chart_model\output_new\tmp'
orig_image_dir = r'D:\work\chart_model\output_new\orig_image_all'

make_dataset.make_dataset(orig_image_dir, dataset_dir)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\Anaconda3\envs\tfgpu\lib\os.py in makedirs(name, mode, exist_ok)
#     220     try:
# --> 221         mkdir(name, mode)
#     222     except OSError:
#
# FileExistsError: [WinError 183] 既に存在するファイルを作成することはできません。: 'D:\\work\\chart_model\\output_new\\tmp\\train\\2'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-784faeac689a> in <module>
#       6 orig_image_dir = r'D:\work\chart_model\output_new\orig_image_all'
#       7
# ----> 8 make_dataset.make_dataset(orig_image_dir, dataset_dir)
#
# ~\jupyter_notebook\tf_2_work\stock_work\chart_model\code\make_dataset.py in make_dataset(orig_image_dir, dataset_dir)
#      44         for p in _train:
#      45             _dir = os.path.join(dataset_dir, 'train', cla)
# ...
